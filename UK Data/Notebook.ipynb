# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid", {"axes.facecolor": ".8"})

# %%
df=pd.read_csv("UK Data.csv")
df
# Out:
#       DateRep  Day  Month  Year  Cases  Deaths Countries and territories  \
# 0    3/1/2020    1      3  2020      5       0            United_Kingdom
# 1    3/2/2020    2      3  2020     13       0            United_Kingdom
# 2    3/3/2020    3      3  2020      4       0            United_Kingdom
# 3    3/4/2020    4      3  2020     11       0            United_Kingdom
# 4    3/5/2020    5      3  2020     34       0            United_Kingdom
# 5    3/6/2020    6      3  2020     30       1            United_Kingdom
# 6    3/7/2020    7      3  2020     48       0            United_Kingdom
# 7    3/8/2020    8      3  2020     43       1            United_Kingdom
# 8    3/9/2020    9      3  2020     67       1            United_Kingdom
# 9   3/10/2020   10      3  2020     48       2            United_Kingdom
# 10  3/11/2020   11      3  2020     52       1            United_Kingdom
# 11  3/12/2020   12      3  2020     83       0            United_Kingdom
# 12  3/13/2020   13      3  2020    134       4            United_Kingdom
# 13  3/14/2020   14      3  2020    117       0            United_Kingdom
# 14  3/15/2020   15      3  2020    433      11            United_Kingdom
# 15  3/16/2020   16      3  2020    251      14            United_Kingdom
# 16  3/17/2020   17      3  2020    152      20            United_Kingdom
# 17  3/18/2020   18      3  2020    407       5            United_Kingdom
# 18  3/19/2020   19      3  2020    680      43            United_Kingdom
#
#    GeoId   Temperature [2 m elevation corrected]   Relative Humidity [2 m]  \
# 0     UK                                 0.75641                        92
# 1     UK                                 2.26641                        86
# 2     UK                                 4.29641                        81
# 3     UK                                 6.57641                        74
# 4     UK                                 9.66641                        72
# 5     UK                                10.29641                        68
# 6     UK                                11.00641                        65
# 7     UK                                11.10641                        64
# 8     UK                                10.11641                        68
# 9     UK                                 9.78641                        70
# 10    UK                                 4.26641                        87
# 11    UK                                 5.23641                        83
# 12    UK                                 6.82641                        77
# 13    UK                                 8.32641                        71
# 14    UK                                16.12641                        73
# 15    UK                                16.23641                        70
# 16    UK                                15.93641                        68
# 17    UK                                14.85641                        70
# 18    UK                                 7.91641                        67
#
#     ...   Cloud Cover Total   Sunshine Duration   Shortwave Radiation  \
# 0   ...                 0.6            30.57028               8.90000
# 1   ...                 5.4            56.55319             133.50000
# 2   ...                 9.0            54.25532             277.68000
# 3   ...                11.0            52.97872             397.83000
# 4   ...                67.0            17.23404             241.19000
# 5   ...                85.0             5.74468             253.65000
# 6   ...                10.0            53.61702             389.82000
# 7   ...                10.0            53.61702             435.21000
# 8   ...               100.0             0.00000             285.69000
# 9   ...                10.0            53.61702             227.84000
# 10  ...                 0.0            35.23333              11.57000
# 11  ...                 0.0            60.00000             134.39000
# 12  ...                 0.0            60.00000             282.13000
# 13  ...                 0.0            60.00000             407.62000
# 14  ...                10.0            53.61702             500.18000
# 15  ...                10.0            53.61702             489.50000
# 16  ...                10.0            53.61702             420.08000
# 17  ...                10.0            53.61702             214.48999
# 18  ...                73.0            13.40425              79.21000
#
#      Wind Speed [10 m]   Wind Direction [10 m]   Wind Gust  Longitude  \
# 0              7.05331               259.11447       21.60  51.5074 N
# 1              6.57959               248.62938       20.16  51.5074 N
# 2              6.59575               223.36343       21.24  51.5074 N
# 3              9.16664               234.46233       22.32  51.5074 N
# 4             19.18450               244.50244       36.00  51.5074 N
# 5             18.50474               247.12634       36.36  51.5074 N
# 6             18.94439               244.15561       37.08  51.5074 N
# 7             19.54004               244.13365       39.24  51.5074 N
# 8             18.85427               246.69511       32.76  51.5074 N
# 9             19.21407               253.07248       35.28  51.5074 N
# 10            14.39546               272.12110       29.88  51.5074 N
# 11            14.69070               274.15967       30.24  51.5074 N
# 12            15.59749               277.85333       30.24  51.5074 N
# 13            16.82332               280.95407       30.60  51.5074 N
# 14            25.95179               264.69910       56.16  51.5074 N
# 15            26.72511               265.42610       57.24  51.5074 N
# 16            27.48572               266.66614       57.96  51.5074 N
# 17            26.93935               267.16590       57.96  51.5074 N
# 18            19.54730                72.55280       33.48  51.5074 N
#
#     Latitude Confirmed  Ccases
# 0   0.1278 W        36      36
# 1   0.1278 W        40       4
# 2   0.1278 W        51      11
# 3   0.1278 W        85      34
# 4   0.1278 W       115      30
# 5   0.1278 W       163      48
# 6   0.1278 W       206      43
# 7   0.1278 W       273      67
# 8   0.1278 W       321      48
# 9   0.1278 W       382      61
# 10  0.1278 W       456      74
# 11  0.1278 W       456       0
# 12  0.1278 W       798     342
# 13  0.1278 W      1140     342
# 14  0.1278 W      1140       0
# 15  0.1278 W      1543     403
# 16  0.1278 W      1950     407
# 17  0.1278 W      2626     676
# 18  0.1278 W      2689      63
#
# [19 rows x 21 columns]

# %%
fig, ax = plt.subplots(figsize=(15,7))
ax.plot(df['Day'], df['Confirmed'],color='red', marker='o', linestyle='dashed',linewidth=2, markersize=12,label="Number of Confirmed Cases")#

plt.xticks(np.arange(1,20,1))
#plt.yticks([0,500,1000,1500,2000,2500])

ax.set_xlabel('Days',fontsize=20)
ax.set_ylabel('Number of Confirmed Cases',fontsize=17)
ax.set_title("Visualization of confirmed cases",fontsize=20)
ax = plt.gca()
ax.legend(prop={'size': 20})
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# %%
feature_names_df = ['Day','Month','Year','Temperature','RH','Precipitation','CC','Sunshine Duration','Shortwave Radiation','Wind Speed [10 m]','Wind Direction [10 m]','Wind Gust']

x_df = df[feature_names_df]
y_df = df['Ccases']
